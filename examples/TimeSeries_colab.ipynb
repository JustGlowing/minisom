# %% [markdown]
# <a href="https://colab.research.google.com/github/microprediction/minisom/blob/master/TimeSeries_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade numpy
# !pip install minisom
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.21.1)
# Requirement already satisfied: minisom in /usr/local/lib/python3.7/dist-packages (2.2.9)

# %%
from minisom import MiniSom
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
# %matplotlib inline
import pandas as pd

# %%
sales_transaction = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/00396/Sales_Transactions_Dataset_Weekly.csv')
data = sales_transaction[[f'Normalized {i}' for i in range(52)]].values
som = MiniSom(8, 8, data.shape[1], sigma=2., learning_rate=0.5, 
              neighborhood_function='gaussian', random_seed=10)
som.pca_weights_init(data)
print("Training...")
som.train_batch(data, 50000, verbose=True)  # random training
print("\n...ready!")
# Out:
# Training...
#  [ 50000 / 50000 ] 100% - 0:00:00 left
#  quantization error: 1.5010568571371044
#
# ...ready!

# %%
win_map = som.win_map(data)

plt.figure(figsize=(16, 16))
the_grid = GridSpec(8, 8)
for position in win_map.keys():
    plt.subplot(the_grid[6-position[1], position[0]])
    plt.plot(np.min(win_map[position], axis=0), color='gray', alpha=.5)
    plt.plot(np.mean(win_map[position], axis=0))
    plt.plot(np.max(win_map[position], axis=0), color='gray', alpha=.5)
plt.show()
